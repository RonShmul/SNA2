# %%
import pandas as pd
import networkx as nx
from networkx.algorithms import community
from IPython.display import display

# %%
def load_network():
    tn_edges = pd.read_csv('thrones-network.csv')
    tn_temp = nx.from_pandas_edgelist(tn_edges, source='Node A', target='Node B', edge_attr='Weight')
    tn = nx.to_undirected(tn_temp)
    return tn

# %%
def preprocess(tn):  # Q1
    remove = [edge for edge in tn.edges().items() if edge[1]['Weight'] < 7]
    remove_list = [remove[i][0] for i in range(len(remove))]
    tn.remove_edges_from(remove_list)
    isolated = list(nx.isolates(tn)) # isolate and remove the unconnected nodes
    tn.remove_nodes_from(isolated)
    return tn

# %%
def graph_attr(tn):
    clustering_coefficient = nx.clustering(tn)
    avg_cluster = nx.average_clustering(tn)
    density = nx.density(tn)
    diameter = nx.diameter(tn)
    avg_path_length = nx.average_shortest_path_length(tn)
    print('clustering for all: ', clustering_coefficient)
    print('average clustering: ', avg_cluster)
    print('density: ', density)
    print('diameter: ', diameter)
    print('avg path length: ', avg_path_length)

# %%
f = load_network()
a = nx.Graph(f)
tn = preprocess(a)
graph_attr(tn)
# Out:
# clustering for all:  {'Aemon': 1.0, 'Grenn': 0.6666666666666666, 'Samwell': 0.2545454545454545, 'Aerys': 1.0, 'Jaime': 0.20588235294117646, 'Robert': 0.6, 'Tyrion': 0.17647058823529413, 'Tywin': 0.37777777777777777, 'Alliser': 1.0, 'Mance': 0.3111111111111111, 'Oberyn': 1.0, 'Arya': 0.2564102564102564, 'Anguy': 0, 'Beric': 0.6666666666666666, 'Bran': 0.3181818181818182, 'Brynden': 1.0, 'Cersei': 0.4642857142857143, 'Gendry': 1.0, 'Gregor': 0.10714285714285714, 'Joffrey': 0.3333333333333333, 'Jon': 0.14210526315789473, 'Rickon': 0.7333333333333333, 'Sandor': 0.4, 'Thoros': 0.6666666666666666, 'Loras': 0.5333333333333333, 'Belwas': 0.5, 'Barristan': 1.0, 'Illyrio': 0, 'Hodor': 1.0, 'Jojen': 0.8333333333333334, 'Meera': 0.8333333333333334, 'Nan': 0, 'Theon': 0.8333333333333334, 'Brienne': 0.6666666666666666, 'Bronn': 1.0, 'Podrick': 0.6666666666666666, 'Lothar': 1.0, 'Walder': 0.6666666666666666, 'Catelyn': 0.26666666666666666, 'Edmure': 0.4, 'Hoster': 1.0, 'Jeyne': 1.0, 'Lysa': 0.3, 'Petyr': 0.6666666666666666, 'Robb': 0.2222222222222222, 'Roslin': 0, 'Sansa': 0.21323529411764705, 'Stannis': 0.19047619047619047, 'Elia': 0, 'Ilyn': 0, 'Meryn': 0.3333333333333333, 'Pycelle': 0, 'Shae': 0.6666666666666666, 'Varys': 1.0, 'Craster': 1.0, 'Daario': 1.0, 'Drogo': 1.0, 'Irri': 1.0, 'Daenerys': 0.07692307692307693, 'Aegon': 0, 'Jorah': 0.6666666666666666, 'Kraznys': 0, 'Missandei': 0, 'Rakharo': 0, 'Rhaegar': 0.3333333333333333, 'Viserys': 1.0, 'Worm': 0, 'Davos': 0.3333333333333333, 'Salladhor': 0, 'Eddard': 0.47619047619047616, 'Eddison': 1.0, 'Gilly': 1.0, 'Qyburn': 0, 'Renly': 0.3333333333333333, 'Tommen': 1.0, 'Janos': 1.0, 'Kevan': 0.5, 'Margaery': 0.6, 'Dalla': 1.0, 'Melisandre': 0.6666666666666666, 'Qhorin': 1.0, 'Rattleshirt': 1.0, 'Styr': 1.0, 'Val': 0.6666666666666666, 'Ygritte': 0.8333333333333334, 'Lancel': 0, 'Olenna': 0, 'Marillion': 1.0, 'Robert Arryn': 0, 'Mace': 0, 'Rickard': 0, 'Walton': 0}
# average clustering:  0.5213002947868004
# density:  0.048733874820831344
# diameter:  9
# avg path length:  3.8205924510272338

# %%
def centrality(tn):
    degree_cen = nx.degree_centrality(tn)
    eigen_cen = nx.eigenvector_centrality(tn)
    closeness_cen = nx.closeness_centrality(tn)
    between_cen = nx.betweenness_centrality(tn)
    return degree_cen, eigen_cen, closeness_cen, between_cen

# %%
def top_10(degree, eigen, closeness, between):
    top_10_degree = dict(sorted(degree.items(), key=lambda x: x[1], reverse=True)[:10])
    top_10_eigen = dict(sorted(eigen.items(), key=lambda x: x[1], reverse=True)[:10])
    top_10_closeness = dict(sorted(closeness.items(), key=lambda x: x[1], reverse=True)[:10])
    top_10_between = dict(sorted(between.items(), key=lambda x: x[1], reverse=True)[:10])
    df_deg = pd.DataFrame.from_dict(top_10_degree, orient='index')
    df_eigen = pd.DataFrame.from_dict(top_10_eigen, orient='index')
    df_close = pd.DataFrame.from_dict(top_10_closeness, orient='index')
    df_between = pd.DataFrame.from_dict(top_10_between, orient='index')
    print('top ten degree centrality', df_deg)
    print('top ten eigen centrality', df_eigen)
    print('top ten closeness centrality', df_close)
    print('top ten between centrality', df_between)
    return top_10_between, top_10_closeness, top_10_eigen, top_10_degree

# %%
def correlation(between, closeness, eigen, degree):
    between_list = list(between.keys())
    closeness_list = list(closeness.keys())
    eigen_list = list(eigen.keys())
    degree_list = list(degree.keys())
    print('correlation between centrality measures: ',list(set(between_list) & set(closeness_list) & set(eigen_list) & set(degree_list)))

# %%
deg, eig, close, bet = centrality(tn)
top_10_be, top_10_cl, top_10_ei, top_10_de = top_10(deg, eig, close, bet)
correlation(top_10_be, top_10_cl, top_10_ei, top_10_de)
# Out:
# top ten degree centrality                  0
# Jon       0.219780
# Tyrion    0.197802
# Robb      0.197802
# Jaime     0.186813
# Sansa     0.186813
# Arya      0.142857
# Daenerys  0.142857
# Bran      0.131868
# Joffrey   0.131868
# Samwell   0.120879
# top ten eigen centrality                 0
# Robb     0.343685
# Sansa    0.322489
# Jaime    0.312683
# Tyrion   0.292689
# Joffrey  0.262783
# Arya     0.236090
# Tywin    0.219292
# Bran     0.201478
# Jon      0.198358
# Cersei   0.189814
# top ten closeness centrality                 0
# Arya     0.402655
# Robb     0.395652
# Tyrion   0.382353
# Sansa    0.372951
# Tywin    0.371429
# Jon      0.365462
# Gregor   0.364000
# Jaime    0.362550
# Bran     0.362550
# Joffrey  0.359684
# top ten between centrality                  0
# Gregor    0.313272
# Elia      0.278388
# Jon       0.271808
# Rhaegar   0.263248
# Daenerys  0.245299
# Arya      0.238963
# Robb      0.229551
# Tyrion    0.182055
# Sansa     0.137770
# Jaime     0.116188
# correlation between centrality measures:  ['Jaime', 'Tyrion', 'Sansa', 'Arya', 'Robb', 'Jon']

# %%
def find_communities(tn):
    communities_generator = community.girvan_newman(tn)
    for i in range(0,3):
        comm = tuple(sorted(c) for c in next(communities_generator))
        comm_dict = dict(enumerate(comm))
        final = dict()
        for key in comm_dict:
            for item in comm_dict[key]:
                final[item] = key
        final_df = pd.DataFrame.from_dict(final, orient='index')
        print('Partition '+str(i))
        display(final_df)

# %%
find_communities(tn)
# Out:
# Partition 0
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Aemon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Aerys</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Alliser</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Anguy</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Arya</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Beric</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Bran</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Brienne</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Bronn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Brynden</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Catelyn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Cersei</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Craster</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Dalla</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Davos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Eddard</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Eddison</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Edmure</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Gendry</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Gilly</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Gregor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Grenn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Hodor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Hoster</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ilyn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jaime</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Janos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jeyne</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Joffrey</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jojen</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Sansa</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Shae</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Stannis</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Styr</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Theon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Thoros</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Tommen</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Tyrion</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Tywin</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Val</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Varys</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Walder</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Walton</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ygritte</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Aegon</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Barristan</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Belwas</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Daario</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Daenerys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Drogo</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Elia</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Illyrio</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Irri</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Jorah</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Kraznys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Missandei</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Rakharo</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Rhaegar</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Viserys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Worm</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>92 rows × 1 columns</p>
# </div>
# Partition 1
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Aemon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Alliser</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Bran</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Craster</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Dalla</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Davos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Eddison</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Gilly</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Grenn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Hodor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Janos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jojen</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Mance</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Meera</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Melisandre</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Nan</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Qhorin</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Rattleshirt</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Salladhor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Samwell</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Stannis</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Styr</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Theon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Val</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ygritte</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Aerys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Anguy</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Arya</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Beric</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Robb</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Robert</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Robert Arryn</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Roslin</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Sandor</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Sansa</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Shae</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Thoros</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tommen</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tyrion</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tywin</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Varys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Walder</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Walton</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Aegon</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Barristan</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Belwas</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Daario</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Daenerys</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Drogo</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Elia</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Illyrio</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Irri</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Jorah</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Kraznys</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Missandei</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Rakharo</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Rhaegar</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Viserys</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Worm</th>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <p>92 rows × 1 columns</p>
# </div>
# Partition 2
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Aemon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Alliser</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Bran</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Craster</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Dalla</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Davos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Eddison</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Gilly</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Grenn</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Hodor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Janos</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jojen</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Jon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Mance</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Meera</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Melisandre</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Nan</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Qhorin</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Rattleshirt</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Salladhor</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Samwell</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Stannis</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Styr</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Theon</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Val</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Ygritte</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Aerys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Anguy</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Arya</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Beric</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Thoros</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tommen</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tyrion</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Tywin</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Varys</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Walton</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Brynden</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Catelyn</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Edmure</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Hoster</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Jeyne</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Lothar</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Roslin</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Walder</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Aegon</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Barristan</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Belwas</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Daario</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Daenerys</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Drogo</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Elia</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Illyrio</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Irri</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Jorah</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Kraznys</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Missandei</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Rakharo</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Rhaegar</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Viserys</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Worm</th>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <p>92 rows × 1 columns</p>
# </div>

# %%
def jaccard_lp(tn):
    pred_jc = nx.jaccard_coefficient(tn)
    pred_dict = {}
    for u, v, p in pred_jc:
        pred_dict[(u, v)] = p
    return sorted(pred_dict.items(), key=lambda x:x[1], reverse=True)[:10]

def preferential_lp(tn):
    pred_pa = nx.preferential_attachment(tn)
    pred_dict = {}
    for u, v, p in pred_pa:
        pred_dict[(u, v)] = p
    return sorted(pred_dict.items(), key=lambda x: x[1], reverse=True)[:10]
